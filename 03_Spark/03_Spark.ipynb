# %% [markdown]
# # 3. Spark
#
# Spark Programming Guide: <https://spark.apache.org/docs/latest/> (use Python API recommended)
# Spark API: <https://spark.apache.org/docs/latest/api/python/index.html>
#
#
# # 3.1 Example Walkthrough
# Follow the Spark examples below. After completion, see Exercise 3.2 and 3.3 at the bottom of this notebook.
#
#
# ### Initialize PySpark

# %%
# !pip install pyspark

# %%
import os, sys

# %%
# Initialize PySpark
APP_NAME = "PySpark Lecture"
SPARK_MASTER="local[1]"
import pyspark
import pyspark.sql
from pyspark.sql import Row
conf=pyspark.SparkConf()
conf=pyspark.SparkConf().setAppName(APP_NAME).set("spark.local.dir", os.path.join(os.getcwd(), "tmp"))
sc = pyspark.SparkContext(master=SPARK_MASTER, conf=conf)
spark = pyspark.sql.SparkSession(sc).builder.appName(APP_NAME).getOrCreate()

print("PySpark initiated...")
# Out:
# PySpark initiated...

# %% [markdown]
# ### Hello, World!
#
# Loading data, mapping it and collecting the records into RAM...

# %%
# !wget https://raw.githubusercontent.com/scalable-infrastructure/exercise-2026/main/data/example.csv
# Out:
# --2026-03-29 14:25:05--  https://raw.githubusercontent.com/scalable-infrastructure/exercise-2026/main/data/example.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 189 [text/plain]
# Saving to: ‘example.csv’
#
# example.csv         100%[===================>]     189  --.-KB/s    in 0s
#
# 2026-03-29 14:25:06 (1.50 MB/s) - ‘example.csv’ saved [189/189]

# %%
# Load the text file using the SparkContext
csv_lines = sc.textFile("example.csv")

# Map the data to split the lines into a list
data = csv_lines.map(lambda line: line.split(","))

# Collect the dataset into local RAM
data.collect()
# Out:
# [['Russell Jurney', 'Relato', 'CEO'],
#  ['Florian Liebert', 'Mesosphere', 'CEO'],
#  ['Don Brown', 'Rocana', 'CIO'],
#  ['Steve Jobs', 'Apple', 'CEO'],
#  ['Donald Trump', 'The Trump Organization', 'CEO'],
#  ['Russell Jurney', 'Data Syndrome', 'Principal Consultant']]

# %% [markdown]
# ### Creating Objects from CSV
#
# Using a function with a map operation to create objects (dicts) as records...

# %%
# Turn the CSV lines into objects
def csv_to_record(line):
    parts = line.split(",")
    record = {
      "name": parts[0],
      "company": parts[1],
      "title": parts[2]
    }
    return record

# Apply the function to every record
records = csv_lines.map(csv_to_record)

# Inspect the first item in the dataset
records.first()
# Out:
# {'name': 'Russell Jurney', 'company': 'Relato', 'title': 'CEO'}

# %% [markdown]
# ### GroupBy
#
# Using the groupBy operator to count the number of jobs per person...

# %%
# Group the records by the name of the person
grouped_records = records.groupBy(lambda x: x["name"])

# Show the first group
grouped_records.first()

# Count the groups
job_counts = grouped_records.map(
  lambda x: {
    "name": x[0],
    "job_count": len(x[1])
  }
)

job_counts.first()

job_counts.collect()
# Out:
# [{'name': 'Russell Jurney', 'job_count': 2},
#  {'name': 'Florian Liebert', 'job_count': 1},
#  {'name': 'Don Brown', 'job_count': 1},
#  {'name': 'Steve Jobs', 'job_count': 1},
#  {'name': 'Donald Trump', 'job_count': 1}]

# %% [markdown]
# ### Map vs FlatMap
#
# Understanding the difference between the map and flatmap operators...

# %%
# Compute a relation of words by line
words_by_line = csv_lines\
  .map(lambda line: line.split(","))

print(words_by_line.collect())

# Compute a relation of words
flattened_words = csv_lines\
  .map(lambda line: line.split(","))\
  .flatMap(lambda x: x)

flattened_words.collect()
# Out:
# [['Russell Jurney', 'Relato', 'CEO'], ['Florian Liebert', 'Mesosphere', 'CEO'], ['Don Brown', 'Rocana', 'CIO'], ['Steve Jobs', 'Apple', 'CEO'], ['Donald Trump', 'The Trump Organization', 'CEO'], ['Russell Jurney', 'Data Syndrome', 'Principal Consultant']]
# ['Russell Jurney',
#  'Relato',
#  'CEO',
#  'Florian Liebert',
#  'Mesosphere',
#  'CEO',
#  'Don Brown',
#  'Rocana',
#  'CIO',
#  'Steve Jobs',
#  'Apple',
#  'CEO',
#  'Donald Trump',
#  'The Trump Organization',
#  'CEO',
#  'Russell Jurney',
#  'Data Syndrome',
#  'Principal Consultant']

# %% [markdown]
# ---
# ## Further Exercises

# %%
# !wget "https://github.com/scalable-infrastructure/exercise-2026/blob/main/data/nasa/NASA_access_log_Jul95.gz?raw=true" -O NASA_access_log_Jul95.gz
# !gzip -d NASA_access_log_Jul95.gz
# Out:
# --2026-03-29 14:25:59--  https://github.com/scalable-infrastructure/exercise-2026/blob/main/data/nasa/NASA_access_log_Jul95.gz?raw=true
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/scalable-infrastructure/exercise-2026/raw/refs/heads/main/data/nasa/NASA_access_log_Jul95.gz [following]
# --2026-03-29 14:25:59--  https://github.com/scalable-infrastructure/exercise-2026/raw/refs/heads/main/data/nasa/NASA_access_log_Jul95.gz
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/scalable-infrastructure/exercise-2026/refs/heads/main/data/nasa/NASA_access_log_Jul95.gz [following]
# --2026-03-29 14:25:59--  https://raw.githubusercontent.com/scalable-infrastructure/exercise-2026/refs/heads/main/data/nasa/NASA_access_log_Jul95.gz
# ...

# %% [markdown]
# ## 3.2 Word Count
#
# Implement a word count using Spark. How many words are in the file `example.csv`?

# %%
## 3.3 HTTP Response Code Analysis

Using the NASA log file, implement a Spark version of the HTTP Response Code Analysis. How many log entries per HTTP Response Code exist?
# Out:
# Object `exist` not found.

# %%
# How many words are in the file example.csv?
print ("Task 3.2: How many words are in the file example.csv?")
# Load the file
csv_lines = sc.textFile("example.csv")
words_comma = csv_lines.flatMap(lambda line: line.split(","))
# Split by space
words_space = words_comma.flatMap(lambda col: col.split())
#Count
word_count = words.count()
word_count_space = words_space.count()
print("All words", words.collect())
print("All words with space", words_space.collect())
print("Total number of words in example.csv:", word_count)
print("Total number of words in example.csv:", word_count_space)
# Out:
# Task 3.2: How many words are in the file example.csv?
# All words ['Russell Jurney', 'Relato', 'CEO', 'Florian Liebert', 'Mesosphere', 'CEO', 'Don Brown', 'Rocana', 'CIO', 'Steve Jobs', 'Apple', 'CEO', 'Donald Trump', 'The Trump Organization', 'CEO', 'Russell Jurney', 'Data Syndrome', 'Principal Consultant']
# All words with space ['Russell', 'Jurney', 'Relato', 'CEO', 'Florian', 'Liebert', 'Mesosphere', 'CEO', 'Don', 'Brown', 'Rocana', 'CIO', 'Steve', 'Jobs', 'Apple', 'CEO', 'Donald', 'Trump', 'The', 'Trump', 'Organization', 'CEO', 'Russell', 'Jurney', 'Data', 'Syndrome', 'Principal', 'Consultant']
# Total number of words in example.csv: 18
# Total number of words in example.csv: 28

# %%
# Exercise 3.3: HTTP Response Code Analysis with Spark (cleaned version)

# Load the NASA log file
log_lines = sc.textFile("NASA_access_log_Jul95")
# Check
print("Print to check", log_lines.take(5))

# Filter out lines with less than 9 columns
##### valid_lines = log_lines.filter(lambda line: len(line.split(" ")) > 9)
valid_lines = log_lines.filter(lambda line: len(line.split()) > 8)
# Extract column 9 (index 8) = the HTTP response code
##### codes = valid_lines.map(lambda line: line.split(" ")[8])
codes = valid_lines.map(lambda line: line.split()[8])


# Map each code to a (code, 1) pair for counting
code_pairs = valid_codes.map(lambda code: (code, 1))

# Sum up all counts per response code
code_counts = code_pairs.reduceByKey(lambda a, b: a + b)

# Sort by count descending and collect results
result = code_counts.sortBy(lambda x: x[1], ascending=False).collect()

# Print clean results
print("HTTP Response Code Analysis:")
for code, count in result:
    print(f"  Code {code}: {count} requests")

# LLMs were used in this exercise to improve the initial implementation,
# especially in the lines marked with ####.
# The original version had a parsing issue because it used split(" "),
# which does not handle multiple consecutive spaces reliably and can produce
# incorrect field positions. This affected the filtering and extraction logic.
# The fix was to use split() instead, which automatically handles arbitrary
# whitespace and therefore parses the log lines correctly.
# Out:
# Print to check ['199.72.81.55 - - [01/Jul/1995:00:00:01 -0400] "GET /history/apollo/ HTTP/1.0" 200 6245', 'unicomp6.unicomp.net - - [01/Jul/1995:00:00:06 -0400] "GET /shuttle/countdown/ HTTP/1.0" 200 3985', '199.120.110.21 - - [01/Jul/1995:00:00:09 -0400] "GET /shuttle/missions/sts-73/mission-sts-73.html HTTP/1.0" 200 4085', 'burger.letters.com - - [01/Jul/1995:00:00:11 -0400] "GET /shuttle/countdown/liftoff.html HTTP/1.0" 304 0', '199.120.110.21 - - [01/Jul/1995:00:00:11 -0400] "GET /shuttle/missions/sts-73/sts-73-patch-small.gif HTTP/1.0" 200 4179']
# HTTP Response Code Analysis:
#   Code 200: 1697914 requests
#   Code 304: 132626 requests
#   Code 302: 46549 requests
#   Code 404: 10714 requests
#   Code 786: 244 requests
#   Code 5866: 186 requests
#   Code 234: 169 requests
#   Code 7071: 168 requests
#   Code 363: 168 requests
#   Code 669: 164 requests
#   Code 1204: 109 requests
#   Code 500: 62 requests
#   Code 403: 54 requests
#   Code 7067: 43 requests
# ...
